# %%
# Import libraries
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from nltk.stem import PorterStemmer
import json
import nltk
import unicodedata
import re
import string
import joblib as joblib
import pickle as pickle

# %%
#Load data
data = pd.read_csv('fakenews.csv')

# %%
# Count the number of rows before removing duplicates
num_rows_before = len(data)

# Remove duplicates
data.drop_duplicates(inplace=True)

# Count the number of rows after removing duplicates
num_rows_after = len(data)

print("Number of rows before removing duplicates:", num_rows_before)
print("Number of rows after removing duplicates:", num_rows_after)
# Out:
# Number of rows before removing duplicates: 3206
# Number of rows after removing duplicates: 3005

# %%
X = data['article']
y = data['label']

# %%
# Split the data into train (90%) and test (10%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# Split the train set into train (70%) and validation (30%) sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, stratify=y_train, random_state=42)

# %%
# Show the number of rows for train, test, and validation sets
print("Train set size:", len(X_train))
print("Validation set size:", len(X_val))
print("Test set size:", len(X_test))
# Out:
# Train set size: 1892
# Validation set size: 812
# Test set size: 301

# %%
# Count the occurrences of each class label in train, test, and validation sets
train_label_counts = y_train.value_counts()
test_label_counts = y_test.value_counts()
val_label_counts = y_val.value_counts()

print("\nTrain set label counts:")
print(train_label_counts)
print("\nTest set label counts:")
print(test_label_counts)
print("\nValidation set label counts:")
print(val_label_counts)
# Out:
# Train set label counts:
# label
# 1    950
# 0    942
# Name: count, dtype: int64
#
# Test set label counts:
# label
# 1    151
# 0    150
# Name: count, dtype: int64
#
# Validation set label counts:
# label
# 1    408
# 0    404
# Name: count, dtype: int64

# %%
# # Text preprocessing
# def remove_diacritics(text):
#     normalized = unicodedata.normalize("NFD", text)
#     return "".join(c for c in normalized if unicodedata.category(c) != "Mn")

# def wordopt(text):
#     text = text.lower()
#     text = remove_diacritics(text)
#     text = re.sub('\[.*?\]', '', text)
#     text = re.sub("\\W", " ", text)
#     text = re.sub('https?://\S+|www\.\S+', '', text)
#     text = re.sub('<.*?>+', '', text)
#     text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
#     text = re.sub('\n', '', text)
#     text = re.sub('\w*\d\w*', '', text)
#     return text

# ps = PorterStemmer()
# with open('stopwords-tl.json', 'r') as f:
#     stopwords = json.load(f)

# def preprocess(text):
#     text = wordopt(text)
#     tokens = nltk.word_tokenize(text)
#     stems = [ps.stem(token) for token in tokens]
#     filtered = [stem for stem in stems if stem not in stopwords]
#     return filtered

# %%
# Text preprocessing

def wordopt(text):
    text = text.lower()
    text = print(re.subn(r'\[.*?\]', '', text)[1])
    text = re.sub(r"\\W", " ", text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    return text

ps = PorterStemmer()
with open('stopwords-tl.json', 'r') as f:
    stopwords = json.load(f)

def preprocess(text):
    text = wordopt(text)
    tokens = nltk.word_tokenize(text)
    stems = [ps.stem(token) for token in tokens]
    filtered = [stem for stem in stems if stem not in stopwords]
    return filtered

# %%
# Apply preprocess function to X_train
X_train = X_train.apply(preprocess)

# Apply preprocess function to X_val
X_val = X_val.apply(preprocess)
# Out:
# ("isang pinay na nagtatrabaho sa dubai bilang isang nanny ang nagwagi ng halagang isang milyong piso matapos siyang mahirang bilang uae 's (united arab emirates) best nanny of 2018. sa 42 nannies na kandidato sa nasabing award, ang 39-anyos na si rosie vargas villa ang nahirang ngayong taon bilang pinakamagaling na yaya dahil sa kanyang dedikasyon sa pag-aalaga ng mga anak ng kanyang employers na mag-a-anim na taon na niyang pinagsisilbihan. ayon sa khaleej times, sa kabuuan ay 17 years na itong nagtatrabaho bilang nanny sa dubai at nanilbihan sa iba't ibang employers. sinorpresa ng awarding committee mula sa rise, isang fintech company na nagpasimula ng pagbibigay ng awards sa mga nanny sa dubai, si rosie nang bisitahin nila ang pinay sa bahay ng kanyang employers. hindi napigilan ni rosie ang mapaluha nang tanggapin niya ang award na uae's best nanny ng 2018 at isang milyong piso. nang tanungin siya kung ano ang plano niyang gawin sa napanalunang isang milyong piso, sinabi ng pinay na tamang-tamang ang pagdating ng premyo dahil ang kaisa-isa niyang anak na babae na ngayon ay 17 years old na ay magkokolehiyo na sa susunod na school year. gagamitin niya ang bahagi ng isang milyon sa edukasyon ng anak. babayaran din ni rosie ang mga utang niya sa pilipinas at balak niyang magpatayo ng sariling bahay kung saan maaari na silang magsamang mag-ina. ani, rosie, babawi siya sa mga panahon na hindi niya nakapiling ang anak. kahit sapat na raw sa kanya ang premyong natanggap para mag-retiro siya, sinabi ni rosie na patuloy siyang magsisilbi sa employer hangga't kaya ng kanyang kalusugan dahil napakabait umano ng mga iyon sa kanya. noong nakaraang taon, isang pinay din - si melanie manansala - ang tinanghal na uae's best nanny. source 1   source 2", 0)
# ('hindi pinalagpas ang iba pang miyembro ng pamilya ni pangulong rodrigo duterte sa panibagong black propaganda video na inilabas ng youtube channel na ang totoong narco list. sa unang video na may titulong ang totoong narco list - episode 1, hayagang iniuugnay si presidential son at dating davao city vice mayor paolo duterte sa kalakaran ng illegal drug trade sa bansa. https://www.youtube.com/watch?v=fhe7bt5wewq isang lalaki na nagpakilalang bikoy ang idinawit ang pangalan ni paolo sa drug trade, sinabi na nagkakamal umano ito ng milyon-milyon mula sa iligal na droga. ibinulgar naman ng mga taga-suporta ng pangulo na peke at scripted lang ang black propaganda video. ipinakita ng kilalang blogger na si thinking pinoy ang kanina-hinalang pirma sa nasabing video. saad ni paolo na may \'stamp\' umano ni trillanes ang nasabing video na ayon pa sa kanya ay isang uri ng paninirang puri. "he may deny it, but the video supposedly showing my involvement in the illegal drug trade in the country has been clearly stamped with the indelible trillanes signature of being a desperate mercenary, one who has done nothing good but attack the government," ayon kay paolo. pero hindi dito nagtatapos ang paninira laban sa pamilya ng pangulo. sa ikalawang video na may titulong ang totoong narco list - episode 2, idinamay na nila ang anak ng pangulo na si veronica "kitty" duterte at kanyang common law partner honeylet avancena. https://www.youtube.com/watch?v=vpl
# ('"we must end their youth recruitment now and we will start by removing all the recruitment propaganda/ vandalism on our own walls, streets and barangays throughout the entire country starting this month." ganito ang naging pahayag ni national youth commission (nyc) chairman ronald cardema kaugnay ng kanilang pangako ng pagkilos laban sa anumang uri ng bandalismo o panghihikayat sa mga kabataan upang sumapi sa new people\'s army (npa), isang galamay ng pinakamalaking komunistang grupo sa ating bansa, ang communist party of the philippines (cpp), batay sa ulat ng cnn news. ayon kay cardema, nakausap na niya ang ilang mga grupong pro-government, kabilang na ang duterte youth movement, na nangakong magbibigay mula p5000 hanggang p10,000 sa sinumang indibidwal na makikipagtulungang tanggalin ang mga pro-npa graffiti. limang libong piso umano ang ipagkakaloob sa sinumang mag-uulat- ito ay \'yung makakakuha ng larawan habang isinasagawa ng isang indibidwal ang bandalismo, gayundin ang pangalan at pagkakakilanlan ng gumagawa nito sa mga daan. halimbawa ay ang mga salitang "mabuhay ang cpp-npa-ndf", gayundin ang "sumapi sa bagong hukbong bayan" at mga katulad pa nito, na kadalasan nating makikitang nakasulat sa iba\'t ibang bahagi ng kalsada. samantala, sampung libo naman daw ang maaaring matanggap ng sinumang magpapakita ng "patriotic effort" sa pamamagitan ng pagsasagawa ng "citizen arrest" at dadalhin ang nasabing mahuhuling vandalizer sa pinakamalapit na himpilan ng pulisya sa lugar. batay kasi sa batas, maaaring magsagawa ng warrant-less arrest ang isang pribadong mamamayan sa sinumang maaktuhang gumawa, gumagawa o magtatangkang gumawa ng bagay na labag sa batas. nakipag-ugnayan na rin umano si cardema sa mga pinuno ng sangguniang kabataan at iba pang mga grupo ng kabataan upang magtulungan sa tuluyang pagtatanggal ng mga pro-npa vandalisms sa bansa, bilang bahagi na rin ng layunin at adhikain ng gobyerno na wakasan na ang mga di-pagkakaunawaan sa pagitan ng pamahalaan at ng mga komunistang grupo. source: cnn news', 0)

# %%
# TF-IDF vectorization
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train.apply(lambda x: ' '.join(x)))
X_val_tfidf = vectorizer.transform(X_val.apply(lambda x: ' '.join(x)))

# %%
# Initializing base models

mnb = MultinomialNB()
lr = LogisticRegression()
rf = RandomForestClassifier()
knn = KNeighborsClassifier()
svm = SVC(probability=True)

base_models = [mnb, lr, rf, knn, svm]
base_names = ['MNB', 'LR', 'RF', 'KNN', 'SVM']
# base_models = [('MNB', mnb), ('LR', lr), ('RF', rf), ('KNN', knn), ('SVM', svm)]

# %%
# Define the parameter grid
param_grid = {'penalty': ['l2'], 'C': [1, 10, 100, 1000], 'solver': ['lbfgs', 'liblinear']}

# Define the GridSearchCV
lr_grid = GridSearchCV(estimator=lr, param_grid=param_grid, scoring='accuracy', cv=5, n_jobs=-1)

# %%
lr_grid.fit(X_train_tfidf, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100, 1000], 'penalty': ['l2'],
#                          'solver': ['lbfgs', 'liblinear']},
#              scoring='accuracy')

# %%
print("Best parameters: ", lr_grid.best_params_)
print("Accuracy: {:.2f}%".format(lr_grid.best_score_ * 100))
# Out:
# Best parameters:  {'C': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
# Accuracy: 94.82%

# %%
best_meta = lr_grid.best_estimator_

# %%
stack = StackingClassifier(estimators=list(zip(base_names, base_models)), final_estimator=best_meta, cv=5)
stack.fit(X_train_tfidf, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('MNB', MultinomialNB()),
#                                ('LR', LogisticRegression()),
#                                ('RF', RandomForestClassifier()),
#                                ('KNN', KNeighborsClassifier()),
#                                ('SVM', SVC(probability=True))],
#                    final_estimator=LogisticRegression(C=1000,
#                                                       solver='liblinear'))

# %%
# Create an empty DataFrame for storing metrics
metrics_df = pd.DataFrame(index=base_names + ['Stacking Model'], columns=['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC'])


# Evaluate base models
for model, name in zip(base_models, base_names):
    model.fit(X_train_tfidf, y_train)
    y_pred = model.predict(X_val_tfidf)
    y_prob = model.predict_proba(X_val_tfidf)[:, 1]  # Probability for positive class for ROC curve

    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)
    auc = roc_auc_score(y_val, y_prob)

    print(f"Metrics for {name}:")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"F1 Score: {f1}")
    print(f"AUC: {auc}")
    print(f"Classification Report:\n{classification_report(y_val, y_pred)}")

    # Store metrics in the DataFrame
    metrics_df.loc[name] = [accuracy, precision, recall, f1, auc]

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_val, y_prob)
    roc_auc = roc_auc_score(y_val, y_prob)

    # Plot ROC Curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'{name} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {name}')
    plt.legend(loc="lower right")
    plt.show()
# Out:
# Metrics for MNB:
# Accuracy: 0.8374384236453202
# Precision: 0.7633587786259542
# Recall: 0.9803921568627451
# F1 Score: 0.8583690987124464
# AUC: 0.9785660551349252
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.69      0.81       404
#            1       0.76      0.98      0.86       408
#
#     accuracy                           0.84       812
#    macro avg       0.87      0.84      0.83       812
# weighted avg       0.87      0.84      0.83       812
# Metrics for LR:
# Accuracy: 0.9322660098522167
# Precision: 0.9584415584415584
# Recall: 0.9044117647058824
# F1 Score: 0.9306431273644389
# AUC: 0.9864710735779461
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93       404
#            1       0.96      0.90      0.93       408
#
#     accuracy                           0.93       812
#    macro avg       0.93      0.93      0.93       812
# weighted avg       0.93      0.93      0.93       812
# Metrics for RF:
# Accuracy: 0.9310344827586207
# Precision: 0.9467005076142132
# Recall: 0.9142156862745098
# F1 Score: 0.9301745635910225
# AUC: 0.9826611337604348
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       404
#            1       0.95      0.91      0.93       408
#
#     accuracy                           0.93       812
#    macro avg       0.93      0.93      0.93       812
# weighted avg       0.93      0.93      0.93       812
# Metrics for KNN:
# Accuracy: 0.8854679802955665
# Precision: 0.8343949044585988
# Recall: 0.9632352941176471
# F1 Score: 0.89419795221843
# AUC: 0.9504101145408659
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.81      0.88       404
#            1       0.83      0.96      0.89       408
#
#     accuracy                           0.89       812
#    macro avg       0.90      0.89      0.88       812
# weighted avg       0.89      0.89      0.88       812
# Metrics for SVM:
# Accuracy: 0.9433497536945813
# Precision: 0.9713541666666666
# Recall: 0.9142156862745098
# F1 Score: 0.9419191919191919
# AUC: 0.9894316637546108
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       404
#            1       0.97      0.91      0.94       408
#
#     accuracy                           0.94       812
#    macro avg       0.94      0.94      0.94       812
# weighted avg       0.94      0.94      0.94       812

# %%
# Evaluate stacking model
stack_y_pred = stack.predict(X_val_tfidf)
stack_y_prob = stack.predict_proba(X_val_tfidf)[:, 1]  # Probability for positive class for ROC curve

stack_accuracy = accuracy_score(y_val, stack_y_pred)
stack_precision = precision_score(y_val, stack_y_pred)
stack_recall = recall_score(y_val, stack_y_pred)
stack_f1 = f1_score(y_val, stack_y_pred)
stack_auc = roc_auc_score(y_val, stack_y_prob)

print("Metrics for Stacking Model:")
print(f"Accuracy: {stack_accuracy}")
print(f"Precision: {stack_precision}")
print(f"Recall: {stack_recall}")
print(f"F1 Score: {stack_f1}")
print(f"AUC: {stack_auc}")
print(f"Classification Report:\n{classification_report(y_val, stack_y_pred)}")

# ROC Curve for stacking model
stack_fpr, stack_tpr, _ = roc_curve(y_val, stack_y_prob)
stack_roc_auc = roc_auc_score(y_val, stack_y_prob)

# Store stacking model metrics in the DataFrame
metrics_df.loc['Stacking Model'] = [stack_accuracy, stack_precision, stack_recall, stack_f1, stack_auc]


# Plot ROC Curve for stacking model
plt.figure(figsize=(8, 6))
plt.plot(stack_fpr, stack_tpr, label=f'Stacking Model (AUC = {stack_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Stacking Model')
plt.legend(loc="lower right")
plt.show()

# Display the comparison table
print("Comparison of Models:")
print(metrics_df)
# Out:
# Metrics for Stacking Model:
# Accuracy: 0.9544334975369458
# Precision: 0.9513381995133819
# Recall: 0.9583333333333334
# F1 Score: 0.9548229548229549
# AUC: 0.9937694137060764
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95       404
#            1       0.95      0.96      0.95       408
#
#     accuracy                           0.95       812
#    macro avg       0.95      0.95      0.95       812
# weighted avg       0.95      0.95      0.95       812
# Comparison of Models:
#                 Accuracy Precision    Recall  F1 Score       AUC
# MNB             0.837438  0.763359  0.980392  0.858369  0.978566
# LR              0.932266  0.958442  0.904412  0.930643  0.986471
# RF              0.931034  0.946701  0.914216  0.930175  0.982661
# KNN             0.885468  0.834395  0.963235  0.894198   0.95041
# SVM              0.94335  0.971354  0.914216  0.941919  0.989432
# Stacking Model  0.954433  0.951338  0.958333  0.954823  0.993769

# %%
# Save the model using joblib
joblib.dump(stack, 'stackmodel_lr_new_more.joblib')
# Out:
# ['stackmodel_lr_new_more.joblib']
